# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv", encoding="latin-1")
data.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
Madagascar = data[(data["Area"] == "Madagascar")& (data["Y2015"])]

# %%
data.sample(2)
# Out:
#        Area Code        Area  Item Code          Item  Element Code  \
# 31555        129  Madagascar       2616     Plantains          5131
# 47623        195     Senegal       2571  Soyabean Oil           674
#
#                                       Element          Unit  Y2014  Y2015  \
# 31555                              Processing   1000 tonnes    0.0    0.0
# 47623  Protein supply quantity (g/capita/day)  g/capita/day    0.0    0.0
#
#        Y2016  Y2017  Y2018
# 31555    0.0    0.0    0.0
# 47623    0.0    0.0    0.0

# %%
data.groupby("Y2014")["Y2014"].count()
data[["Y2014"]] = data[["Y2014"]].fillna(value="mcf")

data.groupby("Y2015")["Y2015"].count()
data[["Y2015"]] = data[["Y2015"]].fillna(value="mcf")

data.groupby("Y2016")["Y2016"].count()
data[["Y2016"]] = data[["Y2016"]].fillna(value="mcf")

data.groupby("Y2017")["Y2017"].count()
data[["Y2017"]] = data[["Y2017"]].fillna(value="mcf")

data.groupby("Y2018")["Y2018"].count()
data[["Y2018"]] = data[["Y2018"]].fillna(value="mcf")

# %%
data.isnull().sum()
# Out:
# Area Code       0
# Area            0
# Item Code       0
# Item            0
# Element Code    0
# Element         0
# Unit            0
# Y2014           0
# Y2015           0
# Y2016           0
# Y2017           0
# Y2018           0
# dtype: int64

# %%
data.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit    Y2014    Y2015  \
# 0           Total Population - Both sexes     1000 persons  38924.0  39728.0
# 1                Domestic supply quantity      1000 tonnes      0.0      0.0
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.0   3379.0
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.9    94.35
# 4      Fat supply quantity (g/capita/day)     g/capita/day    80.06    79.36
#
#      Y2016    Y2017    Y2018
# 0  40551.0  41389.0  42228.0
# 1      0.0      0.0      0.0
# 2   3372.0   3341.0   3322.0
# ...

# %%
# Number of unique countries is 49
data["Area"].unique()
# Out:
# array(['Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso',
#        'Cabo Verde', 'Cameroon', 'Central African Republic', 'Chad',
#        'Comoros', 'Congo', "C?e d'Ivoire", 'Djibouti', 'Egypt',
#        'Eswatini', 'Ethiopia', 'Ethiopia PDR', 'Gabon', 'Gambia', 'Ghana',
#        'Guinea', 'Guinea-Bissau', 'Kenya', 'Lesotho', 'Liberia',
#        'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius',
#        'Morocco', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda',
#        'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone',
#        'South Africa', 'Sudan', 'Sudan (former)', 'Togo', 'Tunisia',
#        'Uganda', 'United Republic of Tanzania', 'Zambia', 'Zimbabwe'],
#       dtype=object)

# %%
# checking for number of rows and columns
data.shape
# Out:
# (60943, 12)

# %%
# What is the total protein supply quantity in Madagascar in 2015
madagascar = data[(data["Area"] == "Madagascar") & (data["Element"] == "Protein supply quantity (g/capita/day)")]
tps= madagascar["Y2015"].sum()
tps
# Out:
# 173.04999999999998

# %%
# Nigeria had the highest sum in 2017
data.groupby("Y2017")["Y2017"].count()
data.groupby("Area").first()
# Out:
#                              Area Code  Item Code             Item  \
# Area
# Algeria                              4       2501       Population
# Angola                               7       2501       Population
# Benin                               53       2501       Population
# Botswana                            20       2501       Population
# Burkina Faso                       233       2501       Population
# C?e d'Ivoire                       107       2501       Population
# Cabo Verde                          35       2501       Population
# Cameroon                            32       2501       Population
# Central African Republic            37       2501       Population
# Chad                                39       2501       Population
# Comoros                             45       2781   Fish, Body Oil
# Congo                               46       2501       Population
# Djibouti                            72       2501       Population
# ...

# %%
# The total number of the sum of processing in 2017 is 292836.00
data.groupby("Element").sum()
# Out:
# C:\Users\MAC\AppData\Local\Temp\ipykernel_8904\2817832392.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby("Element").sum()
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# ...

# %%
# 2014 had the highest stock variation
data.groupby("Element").sum()
# Out:
# C:\Users\MAC\AppData\Local\Temp\ipykernel_8904\2817832392.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby("Element").sum()
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# ...

# %%
# 2015 has the least correlation with element code
data.corr()
# Out:
# C:\Users\MAC\AppData\Local\Temp\ipykernel_8904\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# ...

# %%
data.dropna().describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  57784.000000  57784.000000  57784.000000   57784.000000   57784.000000
# mean     134.499342   2690.495656   3745.422868     137.831770     138.990488
# std       72.651212    146.625825   2217.914615    1588.660769    1625.441821
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2563.000000    674.000000       0.000000       0.000000
# 50%      136.000000   2633.000000   5142.000000       0.140000       0.130000
# 75%      196.000000   2781.000000   5301.000000       9.000000       9.000000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   57784.000000   57784.000000   57784.000000
# mean      140.376380     144.927790     148.027664
# std      1662.732983    1695.436448    1735.920219
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
data.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
# percentage of missing data
percentage = data.isnull().sum() *100/len(data)
print(round(percentage,3))
# Out:
# Area Code       0.000
# Area            0.000
# Item Code       0.000
# Item            0.000
# Element Code    0.000
# Element         0.000
# Unit            0.000
# Y2014           2.607
# Y2015           2.540
# Y2016           2.519
# Y2017           2.471
# Y2018           2.356
# dtype: float64

# %%
data.groupby("Item").sum()
# Out:
# C:\Users\MAC\AppData\Local\Temp\ipykernel_8904\2168619159.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby("Item").sum()
#                      Area Code  Item Code  Element Code      Y2014      Y2015  \
# Item
# Alcohol, Non-Food        38447     752497       1515090    2403.00    2180.00
# Alcoholic Beverages      75016    1649136       2171381  102410.11   98783.72
# Animal Products          18060     397035         90990   11935.65   11811.73
# Animal fats              85279    1882494       2567303  209460.54  200675.72
# Apples and products      69280    1352989       1920418    9499.23   10559.15
# ...                        ...        ...           ...        ...        ...
# Vegetables, Other        77779    1518715       2275409  155038.96  158104.08
# ...
